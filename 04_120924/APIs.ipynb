# %% [markdown]
# # Application Programming Interface
# - How software talks to Software
# - Endpoints = Methods
# - We will discussion WebAPIs
#     - What do we need:
#         - API Key / Authentication
#         - URL
#             - Base
#             - Endpoint
#         - Request Header: Metadata associated with our request
#         - Parameters: configuration for API call
#         - Payload / Data: Response that we get back

# %%
# Web APIs
# Processing text = JSON
# Request Header: application/JSON, plain/text, image/jpeg (MIME Types)

import json

# Two types of JSON representations
# JSON Data run in my program = String
# JSON Data pushed through an API = Binary

employees = [
    {
        'name': 'Digs',
        'Player1': {
            'name': 'Sam',
            'position': 'libero',
            'number': 19
        }
    },
    {
        'name': 'John',
        'company': 'Skillstorm'
    }
]

out_file = './data/output.json'

# Will create a binary representation
with open(out_file, 'w') as f:
    json.dump(employees, f, indent=4)

# %%
#  Creates a String Representation of our JSON
json_text = json.dumps(employees)

print(type(json_text))
print(json_text)
# Out:
# <class 'str'>
# [{"name": "Digs", "Player1": {"name": "Sam", "position": "libero", "number": 19}}, {"name": "John", "company": "Skillstorm"}]

# %%
# To read JSON out of a file use .load()

with open(out_file) as f:
    data = json.load(f)
    print(type(data))
    print(data)
# Out:
# <class 'list'>
# [{'name': 'Digs', 'Player1': {'name': 'Sam', 'position': 'libero', 'number': 19}}, {'name': 'John', 'company': 'Skillstorm'}]

# %%
# If we have a String of JSON we can use .loads()

json_dict = json.loads(json_text)
print(type(json_dict))
print(json_dict)
# Out:
# <class 'list'>
# [{'name': 'Digs', 'Player1': {'name': 'Sam', 'position': 'libero', 'number': 19}}, {'name': 'John', 'company': 'Skillstorm'}]

# %% [markdown]
# # Web APIs
#
# ## RESTful API
# - Simple API that will send full objects
# - Majority of Web APIs are RESTful
#
# ## SOAP API
# - Simple Object Access Protocol
# - Passes parameters so that objects can be built in the applications native code
# - wsdl (Web Services Description Language) schema
# - Popular in heavily regulated industries - healthcare, military, government
#
# ## XML - RPC (Remote Procedure Call: Excecutin code directly on another machine)
# - Generally not public facing
# - Apache Spark uses this to facilitate communication between nodes
#
# ## Websocket
# - Full two-way communication structure
# - Push system instead of polling
# - Realtime communication
#
# # API Request
#
# ## URL
# - Base
# - Endpoint
# - `https://api.example.com/v1/endpoint`
#
# ## Methods
# - GET - Retrieval
# - POST - Create information
# - PUT - Update the existing API Resource
# - DELETE - Delete a resource
# - Requests library to use these methods (requests.get(), requests.post(), ...)
#
# ## Parameters
# - Configuration settings
#
# ## Body/Payload/Data
# - Actual information that we requested
#
# ## Authentication Methods
# - No authentication
# - Username/Password
# - API key
#     - Encryption Standard
#     - Issued by the API Owner
#     - One per person
# - OAuth
#     - 2.x
#     - Typically used for App-App communication
#     - Token Refresh - Set amount of time the OAuth token will cycle

# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()
api_key_env = os.environ['nytimes_api_key']

# When building a URL be consistent with your slashes
base_url = 'https://api.nytimes.com'
books_api = '/svc/books/v3'
hardcover_endpoint = '/lists/current/hardcover-fiction.json'

books_url = base_url + books_api + hardcover_endpoint

# Check the docs for what parameters you need
params = { 'api-key': api_key_env }

response = requests.get(books_url, params)

response
# Out:
# <Response [200]>

# %%
api_key = ''
api_key_env = ''

# 3 options for protecting our data
# Option 1: is creating a constants.py
from constants import api_key

# Option 2: environment variables
# os.environ['API_KEY'] = '9gGHVopbnNxSOyBiDstcMH6RSM0jQaii'
# api_key = os.environ['API_KEY']

# Option 3: .env file
from dotenv import load_dotenv
load_dotenv()
api_key_env = os.environ['nytimes_api_key']

print(api_key_env)
# Out:
# 9gGHVopbnNxSOyBiDstcMH6RSM0jQaii

# %%
print(response)

# Response codes:
# 200 = Success
# 400 = Client Side Error
# 500 = Server Side Error
# Out:
# <Response [200]>

# %%
data = response.json()

data["results"]["books"]
# Out:
# [{'rank': 1,
#   'rank_last_week': 5,
#   'weeks_on_list': 43,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1250178630',
#   'primary_isbn13': '9781250178633',
#   'publisher': "St. Martin's",
#   'description': 'In 1965, a nursing student follows her brother to serve during the Vietnam War and returns to a divided America.',
#   'price': '0.00',
#   'title': 'THE WOMEN',
#   'author': 'Kristin Hannah',
#   'contributor': 'by Kristin Hannah',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781250178633.jpg',
#   'book_image_width': 333,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1250178630?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1250178630', 'isbn13': '9781250178633'},
#    {'isbn10': '1250178657', 'isbn13': '9781250178657'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1250178630?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781250178633?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250178633'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BWOMEN%2FKristin%2BHannah%2F9781250178633'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781250178633'}],
#   'book_uri': 'nyt://book/9ce735af-71cf-5ff3-a367-43ee07e3fdd7'},
#  {'rank': 2,
#   'rank_last_week': 4,
#   'weeks_on_list': 22,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0385550367',
#   'primary_isbn13': '9780385550369',
#   'publisher': 'Doubleday',
#   'description': "A reimagining of “Adventures of Huckleberry Finn” shines a different light on Mark Twain's classic, revealing new facets of the character of Jim.",
#   'price': '0.00',
#   'title': 'JAMES',
#   'author': 'Percival Everett',
#   'contributor': 'by Percival Everett',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780385550369.jpg',
#   'book_image_width': 333,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0385550367?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0385550367', 'isbn13': '9780385550369'},
#    {'isbn10': '0385550375', 'isbn13': '9780385550376'},
#    {'isbn10': '0593821254', 'isbn13': '9780593821251'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0385550367?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780385550369?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385550369'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FJAMES%2FPercival%2BEverett%2F9780385550369'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9780385550369'}],
#   'book_uri': 'nyt://book/5788b098-426a-5f2c-a318-475692df69ee'},
#  {'rank': 3,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0316402680',
#   'primary_isbn13': '9780316402682',
#   'publisher': 'Little, Brown',
#   'description': 'The 33rd book in the Alex Cross series. Three candidates to the Supreme Court are violently attacked.',
#   'price': '0.00',
#   'title': 'THE HOUSE OF CROSS',
#   'author': 'James Patterson',
#   'contributor': 'by James Patterson',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780316402682.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0316402680?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0316402680', 'isbn13': '9780316402682'},
#    {'isbn10': '0316408913', 'isbn13': '9780316408912'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0316402680?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780316402682?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316402682'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BHOUSE%2BOF%2BCROSS%2FJames%2BPatterson%2F9780316402682'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9780316402682'}],
#   'book_uri': 'nyt://book/0989b374-88d3-5235-b473-165afbad0b07'},
#  {'rank': 4,
#   'rank_last_week': 1,
#   'weeks_on_list': 2,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1668003139',
#   'primary_isbn13': '9781668003138',
#   'publisher': 'Atria',
#   'description': 'The 31st book in the Stephanie Plum series. Caught between two fiancés and not knowing what to do, Plum gets back to business as a bounty hunter.',
#   'price': '0.00',
#   'title': 'NOW OR NEVER',
#   'author': 'Janet Evanovich',
#   'contributor': 'by Janet Evanovich',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781668003138.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1668003139?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1668003139', 'isbn13': '9781668003138'},
#    {'isbn10': '1668003163', 'isbn13': '9781668003169'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1668003139?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781668003138?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781668003138'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FNOW%2BOR%2BNEVER%2FJanet%2BEvanovich%2F9781668003138'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781668003138'}],
#   'book_uri': 'nyt://book/81c14f5d-f0d6-5cc5-9f1f-1f3b568d585d'},
#  {'rank': 5,
#   'rank_last_week': 10,
#   'weeks_on_list': 10,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0593449592',
#   'primary_isbn13': '9780593449592',
#   'publisher': 'Random House',
#   'description': 'A man in search of the father he never knew encounters a single mom and rumors circulate of the nearby appearance of a white deer.',
#   'price': '0.00',
#   'title': 'COUNTING MIRACLES',
#   'author': 'Nicholas Sparks',
#   'contributor': 'by Nicholas Sparks',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780593449592.jpg',
#   'book_image_width': 330,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0593449592?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0593449592', 'isbn13': '9780593449592'},
#    {'isbn10': '0593449606', 'isbn13': '9780593449608'},
#    {'isbn10': '0593912616', 'isbn13': '9780593912614'},
#    {'isbn10': '0593912608', 'isbn13': '9780593912607'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0593449592?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780593449592?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780593449592'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FCOUNTING%2BMIRACLES%2FNicholas%2BSparks%2F9780593449592'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9780593449592'}],
#   'book_uri': 'nyt://book/974caeee-6bf0-524c-809c-29bfdd99d65f'},
#  {'rank': 6,
#   'rank_last_week': 8,
#   'weeks_on_list': 56,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1649374178',
#   'primary_isbn13': '9781649374172',
#   'publisher': 'Red Tower',
#   'description': 'The second book in the Empyrean series. Violet Sorrengail’s next round of training under the new vice commandant might require her to betray the man she loves.',
#   'price': '0.00',
#   'title': 'IRON FLAME',
#   'author': 'Rebecca Yarros',
#   'contributor': 'by Rebecca Yarros',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781649374172.jpg',
#   'book_image_width': 309,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1649374178?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1649374178', 'isbn13': '9781649374172'},
#    {'isbn10': '1705085083', 'isbn13': '9781705085080'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1649374178?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781649374172?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781649374172'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FIRON%2BFLAME%2FRebecca%2BYarros%2F9781649374172'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781649374172'}],
#   'book_uri': 'nyt://book/d3c570c9-3c3a-5c8b-a740-85ea5e92bfc9'},
#  {'rank': 7,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1668014882',
#   'primary_isbn13': '9781668014882',
#   'publisher': 'Gallery',
#   'description': 'An emergency medical technician develops a relationship with an author who is not completely honest with her.',
#   'price': '0.00',
#   'title': 'CHRISTMAS IN BETHEL',
#   'author': 'Richard Paul Evans',
#   'contributor': 'by Richard Paul Evans',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781668014882.jpg',
#   'book_image_width': 356,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1668014882?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1668014882', 'isbn13': '9781668014882'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1668014882?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781668014882?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781668014882'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FCHRISTMAS%2BIN%2BBETHEL%2FRichard%2BPaul%2BEvans%2F9781668014882'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781668014882'}],
#   'book_uri': 'nyt://book/406357a6-0813-52b8-87f0-c901ce71a332'},
#  {'rank': 8,
#   'rank_last_week': 6,
#   'weeks_on_list': 3,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1538757907',
#   'primary_isbn13': '9781538757901',
#   'publisher': 'Grand Central',
#   'description': 'The third book in the 6:20 Man series. Devine digs into the deaths of an orphan’s parents and uncovers a large conspiracy.',
#   'price': '0.00',
#   'title': 'TO DIE FOR',
#   'author': 'David Baldacci',
#   'contributor': 'by David Baldacci',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781538757901.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1538757907?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1538757907', 'isbn13': '9781538757901'},
#    {'isbn10': '1538757931', 'isbn13': '9781538757932'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1538757907?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781538757901?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781538757901'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTO%2BDIE%2BFOR%2FDavid%2BBaldacci%2F9781538757901'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781538757901'}],
#   'book_uri': 'nyt://book/77d78244-71a9-50a4-b35b-9f2a4eda48e5'},
#  {'rank': 9,
#   'rank_last_week': 2,
#   'weeks_on_list': 2,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1250288770',
#   'primary_isbn13': '9781250288776',
#   'publisher': "St. Martin's",
#   'description': 'The second book in the Lost Bride series. In a haunted mansion, Sonya receives a vision of a bride murdered on her wedding day.',
#   'price': '0.00',
#   'title': 'THE MIRROR',
#   'author': 'Nora Roberts',
#   'contributor': 'by Nora Roberts',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781250288776.jpg',
#   'book_image_width': 329,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1250288770?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1250288770', 'isbn13': '9781250288776'},
#    {'isbn10': '1250288789', 'isbn13': '9781250288783'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1250288770?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781250288776?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250288776'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BMIRROR%2FNora%2BRoberts%2F9781250288776'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781250288776'}],
#   'book_uri': 'nyt://book/0f91eb84-2885-5a63-8f7f-456b7d920cbd'},
#  {'rank': 10,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': 'None',
#   'primary_isbn13': '9780063391086',
#   'publisher': 'Morrow',
#   'description': 'A misunderstood girl named Elphaba is declared a witch; the basis of the musical and the film.',
#   'price': '0.00',
#   'title': 'WICKED',
#   'author': 'Gregory Maguire',
#   'contributor': 'by Gregory Maguire',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780061792946.jpg',
#   'book_image_width': 330,
#   'book_image_height': 495,
#   'amazon_product_url': 'https://www.amazon.com/Wicked-Movie-tie-Inspiration-Broadway/dp/0062852841?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': 'https://www.nytimes.com/1995/10/24/books/books-of-the-times-let-s-get-this-straight-glinda-was-the-bad-one.html',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0061792942', 'isbn13': '9780061792946'},
#    {'isbn10': '0061350966', 'isbn13': '9780061350962'},
#    {'isbn10': '0060987103', 'isbn13': '9780060987107'},
#    {'isbn10': '0060745908', 'isbn13': '9780060745905'},
#    {'isbn10': '0062852841', 'isbn13': '9780062852847'},
#    {'isbn10': '0063398346', 'isbn13': '9780063398344'},
#    {'isbn10': '0062853198', 'isbn13': '9780062853196'},
#    {'isbn10': '0061649422', 'isbn13': '9780061649424'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/Wicked-Movie-tie-Inspiration-Broadway/dp/0062852841?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780063391086?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780063391086'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FWICKED%2FGregory%2BMaguire%2F9780063391086'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9780063391086'}],
#   'book_uri': 'nyt://book/d3c20344-e83d-5b61-ac79-cd44459aaa92'},
#  {'rank': 11,
#   'rank_last_week': 0,
#   'weeks_on_list': 15,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1668037718',
#   'primary_isbn13': '9781668037713',
#   'publisher': 'Scribner',
#   'description': 'A dozen short stories that explore darkness in literal and metaphorical forms.',
#   'price': '0.00',
#   'title': 'YOU LIKE IT DARKER',
#   'author': 'Stephen King',
#   'contributor': 'by Stephen King',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781668037713.jpg',
#   'book_image_width': 329,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1668037718?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1668037718', 'isbn13': '9781668037713'},
#    {'isbn10': '1668037734', 'isbn13': '9781668037737'},
#    {'isbn10': '1797174622', 'isbn13': '9781797174624'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1668037718?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781668037713?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781668037713'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FYOU%2BLIKE%2BIT%2BDARKER%2FStephen%2BKing%2F9781668037713'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781668037713'}],
#   'book_uri': 'nyt://book/84fc5c9e-1607-56f8-afcd-0ee37bfc8237'},
#  {'rank': 12,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1496755545',
#   'primary_isbn13': '9781496755544',
#   'publisher': 'Kensington',
#   'description': 'A ghost hunter is stalked by a demon and a killer is at odds with a cult that once controlled him.',
#   'price': '0.00',
#   'title': 'HER SOUL TO TAKE',
#   'author': 'Harley Laroux',
#   'contributor': 'by Harley Laroux',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781496755544.jpg',
#   'book_image_width': 287,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1496755545?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1496755545', 'isbn13': '9781496755544'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1496755545?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781496755544?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781496755544'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FHER%2BSOUL%2BTO%2BTAKE%2FHarley%2BLaroux%2F9781496755544'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9781496755544'}],
#   'book_uri': 'nyt://book/d90de7aa-acdc-5ae6-9b49-dec95a756b09'},
#  {'rank': 13,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': 'None',
#   'primary_isbn13': '9798874866358',
#   'publisher': 'Blackstone',
#   'description': 'A criminal defense attorney vows to defend her husband after he is accused of murdering his mistress.',
#   'price': '0.00',
#   'title': 'THE PERFECT MARRIAGE',
#   'author': 'Jeneva Rose',
#   'contributor': 'by Jeneva Rose',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9798874866358.jpg',
#   'book_image_width': 437,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/B0D9KL1WJK?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1913419657', 'isbn13': '9781913419653'},
#    {'isbn10': '1504071573', 'isbn13': '9781504071574'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/B0D9KL1WJK?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9798874866358?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9798874866358'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BPERFECT%2BMARRIAGE%2FJeneva%2BRose%2F9798874866358'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9798874866358'}],
#   'book_uri': 'nyt://book/a666cc3c-4038-589f-8bb3-ee5921282524'},
#  {'rank': 14,
#   'rank_last_week': 0,
#   'weeks_on_list': 9,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0374602638',
#   'primary_isbn13': '9780374602635',
#   'publisher': 'Farrar, Straus and Giroux',
#   'description': 'After the passing of their father, seemingly different brothers engage in relationships and seek ways to cope.',
#   'price': '0.00',
#   'title': 'INTERMEZZO',
#   'author': 'Sally Rooney',
#   'contributor': 'by Sally Rooney',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780374602635.jpg',
#   'book_image_width': 326,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0374602638?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0374602638', 'isbn13': '9780374602635'},
#    {'isbn10': '0374602646', 'isbn13': '9780374602642'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0374602638?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780374602635?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780374602635'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FINTERMEZZO%2FSally%2BRooney%2F9780374602635'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9780374602635'}],
#   'book_uri': 'nyt://book/a3bcdd05-312a-566b-90ec-df50e894bce6'},
#  {'rank': 15,
#   'rank_last_week': 11,
#   'weeks_on_list': 6,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0593725808',
#   'primary_isbn13': '9780593725801',
#   'publisher': 'Delacorte',
#   'description': 'The 29th book in the Jack Reacher series. Reacher wakes up in a precarious position with no memory of how he got there.',
#   'price': '0.00',
#   'title': 'IN TOO DEEP',
#   'author': 'Lee Child and Andrew Child',
#   'contributor': 'by Lee Child and Andrew Child',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780593725801.jpg',
#   'book_image_width': 329,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0593725808?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0593725808', 'isbn13': '9780593725801'},
#    {'isbn10': '0593725816', 'isbn13': '9780593725818'},
#    {'isbn10': '0593916476', 'isbn13': '9780593916476'},
#    {'isbn10': '0593916468', 'isbn13': '9780593916469'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0593725808?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780593725801?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780593725801'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FIN%2BTOO%2BDEEP%2FLee%2BChild%2Band%2BAndrew%2BChild%2F9780593725801'},
#    {'name': 'Bookshop.org',
#     'url': 'https://bookshop.org/a/3546/9780593725801'}],
#   'book_uri': 'nyt://book/ad92d0e0-0430-55b8-a423-b78d5fb8fa07'}]

# %%
book_titles = [books['title'] for books in data['results']['books']]

book_titles
# Out:
# ['THE WOMEN',
#  'JAMES',
#  'THE HOUSE OF CROSS',
#  'NOW OR NEVER',
#  'COUNTING MIRACLES',
#  'IRON FLAME',
#  'CHRISTMAS IN BETHEL',
#  'TO DIE FOR',
#  'THE MIRROR',
#  'WICKED',
#  'YOU LIKE IT DARKER',
#  'HER SOUL TO TAKE',
#  'THE PERFECT MARRIAGE',
#  'INTERMEZZO',
#  'IN TOO DEEP']

# %%
# We can check the metadata details of our response
response.headers
# Out:
# {'Date': 'Tue, 10 Dec 2024 14:33:05 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'Apache/2.4.38 (Debian)', 'X-Powered-By': 'PHP/7.4.13', 'Via': '1.1 google, 1.1 varnish', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Age': '1019', 'X-Served-By': 'cache-bfi-kbfi7400081-BFI', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1733841186.715523,VS0,VE1', 'Vary': 'Accept-Encoding', 'x-nyt-mktg-group': 'group1', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Accept, Content-Type, X-Forwarded-For, X-Prototype-Version, X-Requested-With', 'Access-Control-Expose-Headers': 'Content-Length, X-JSON', 'Access-Control-Allow-Methods': 'GET, OPTIONS', 'Strict-Transport-Security': 'max-age=63072000; preload; includeSubdomains'}

# %%
response.encoding
# Out:
# 'UTF-8'

# %%
response.status_code
# Out:
# 200
